# %% [markdown]
# <a href="https://colab.research.google.com/github/djbradyAtOpticalSciencesArizona/computationalImaging/blob/master/images/natureOfImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is an image
# ###David Brady
# ### University of Arizona
#
# Chapter 1 of **Computational Optical Imaging**

# %% [markdown]
# ### Python modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.rcParams.update({'font.size': 22})

# %%
# !wget --no-check-certificate --content-disposition 'https://github.com/djbradyAtOpticalSciencesArizona/computationalImaging/raw/master/images/pipe.png'
# Out:
# --2023-05-26 00:00:45--  https://github.com/djbradyAtOpticalSciencesArizona/computationalImaging/raw/master/images/pipe.png
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/djbradyAtOpticalSciencesArizona/computationalImaging/master/images/pipe.png [following]
# --2023-05-26 00:00:45--  https://raw.githubusercontent.com/djbradyAtOpticalSciencesArizona/computationalImaging/master/images/pipe.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23525 (23K) [image/png]
# Saving to: ‘pipe.png’
#
# pipe.png            100%[===================>]  22.97K  --.-KB/s    in 0.002s
#
# ...

# %%
pipe = np.asarray(Image.open("pipe.png"))
pipe=pipe[:,:,1]

# %%
pipe.shape
# Out:
# (105, 125)

# %%
plt.figure(figsize=(10,10))
plt.imshow(pipe,cmap='gray')
plt.savefig('pipe.pdf')

# %%
np.set_printoptions(threshold=np.inf)
np.set_printoptions(edgeitems=30, linewidth=100000)
print(pipe)
# Out:
# [[255 255 255 255 255 250 233 197 142  94  78  88  84  77  73  68  93 151 197 232 245 252 255 255 255 255 255 255 254 245 227 231 251 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
# ...
